# %%
# prompt: delete column in dataframe

df.drop('column_name', axis=1, inplace=True)

# %%
import requests
import json
import pandas as pd

# %%
df = pd.read_json('https://s3.amazonaws.com/open-to-cors/assignment.json')

# %%
df.head()
# Out:
#       count                                           products
# 1128   1000  {'subcategory': 'mobile', 'title': 'Samsung Me...
# 1148   1000  {'subcategory': 'mobile', 'title': 'Apple iPho...
# 1170   1000  {'subcategory': 'mobile', 'title': 'Samsung Ga...
# 12     1000  {'subcategory': 'mobile', 'title': 'Apple iPho...
# 1267   1000  {'subcategory': 'mobile', 'title': 'Nokia C2',...

# %%
df['products'].apply(pd.Series)
# Out:
#      subcategory                     title  price popularity
# 1128      mobile  Samsung Metro DUOS C3322   2422       4396
# 1148      mobile       Apple iPhone 4 16GB  26999       1640
# 1170      mobile   Samsung Galaxy S2 I9100  20050       2855
# 12        mobile     Apple iPhone 3GS 16GB  12179       2579
# 1267      mobile                  Nokia C2   2239        597
# ...          ...                       ...    ...        ...
# 7411      mobile      HTC Desire 326G Plus   9800        274
# 754       mobile        Samsung Chat C3222   3795        569
# 755       mobile       Samsung Metro C3530   3907        296
# 932       mobile             Motorola Defy   5200       1030
# 934       mobile               Nokia X2-01   3721        442
#
# [1000 rows x 4 columns]

# %%
df = pd.concat([df['products'].apply(pd.Series), df.drop('products', axis = 1)], axis = 1)

# %%
df.head()
# Out:
#      subcategory                     title  price popularity  count
# 1128      mobile  Samsung Metro DUOS C3322   2422       4396   1000
# 1148      mobile       Apple iPhone 4 16GB  26999       1640   1000
# 1170      mobile   Samsung Galaxy S2 I9100  20050       2855   1000
# 12        mobile     Apple iPhone 3GS 16GB  12179       2579   1000
# 1267      mobile                  Nokia C2   2239        597   1000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1128 to 934
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   subcategory  1000 non-null   object
#  1   title        1000 non-null   object
#  2   price        1000 non-null   object
#  3   popularity   1000 non-null   object
#  4   count        1000 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 46.9+ KB

# %%
df.drop('count', axis=1, inplace=True)

# %%
df.head()
# Out:
#      subcategory                     title  price popularity
# 1128      mobile  Samsung Metro DUOS C3322   2422       4396
# 1148      mobile       Apple iPhone 4 16GB  26999       1640
# 1170      mobile   Samsung Galaxy S2 I9100  20050       2855
# 12        mobile     Apple iPhone 3GS 16GB  12179       2579
# 1267      mobile                  Nokia C2   2239        597

# %%
df.sort_values(by=['popularity'])
# Out:
#      subcategory                               title  price popularity
# 4397      mobile                Spice Stellar Mi-600   5269       1001
# 3420      mobile                    Gionee Long L800   1818       1003
# 4026      mobile        Micromax Canvas Duet 2 EG111   6779       1009
# 4727      mobile          Celkon Millennium Glory Q5   4499       1013
# 5157      tablet  Lenovo A7-30 Tablet 8 GB (WiFi 2G)   5825       1015
# ...          ...                                 ...    ...        ...
# 2618      mobile                      BlackBerry Q10  20621        985
# 2244      mobile                              HTC 8S  10999        987
# 4716      mobile                   Lava Iris X1 8 GB  12190        988
# 4805      mobile                 Sony Xperia E3 Dual   9299       9895
# 5059      tablet                      IBall 6351-Q40   3633        995
#
# [1000 rows x 4 columns]
